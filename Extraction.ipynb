# %%
import os
import requests
import json

import pandas as pd
print("pandas: %s" % pd.__version__)
# Out:
# pandas: 1.0.1

# %%
# Get all the raw data
response = requests.get("https://min-api.cryptocompare.com/data/all/coinlist")
data = json.loads(response.text)["Data"]

# %%
# Convert raw data into a dataframe and pick the columns
df = pd.DataFrame.from_dict(
    data, 
    orient="index",
    columns=[
        "CoinName",
        "Algorithm",
        "IsTrading",
        "ProofType",
        "TotalCoinsMined",
        "MaxSupply"
    ]
)
df
# Out:
#         CoinName Algorithm  IsTrading ProofType  TotalCoinsMined  MaxSupply
# 42       42 Coin    Scrypt       True   PoW/PoS     0.000000e+00        0.0
# 300    300 token       N/A       True       N/A     3.000000e+02      300.0
# 365      365Coin       X11       True   PoW/PoS     0.000000e+00        0.0
# 404      404Coin    Scrypt       True   PoW/PoS     0.000000e+00        0.0
# 433    433 Token       N/A      False       N/A              NaN        NaN
# ...          ...       ...        ...       ...              ...        ...
# PANDO      Pando       N/A       True       N/A     2.000000e+09       -1.0
# 1INCH      1inch       N/A       True       N/A     1.500000e+09       -1.0
# WEB      Webcoin       N/A       True       N/A     1.000000e+10       -1.0
# TUSD    True USD       N/A       True       N/A     9.808949e+08       -1.0
# SIP    Space SIP       N/A      False       N/A     9.997269e+08       -1.0
#
# [7304 rows x 6 columns]

# %%
# Rename column to work with legacy systems
df = df.rename(columns={"MaxSupply": "TotalCoinSupply"})
df
# Out:
#         CoinName Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 42       42 Coin    Scrypt       True   PoW/PoS     0.000000e+00
# 300    300 token       N/A       True       N/A     3.000000e+02
# 365      365Coin       X11       True   PoW/PoS     0.000000e+00
# 404      404Coin    Scrypt       True   PoW/PoS     0.000000e+00
# 433    433 Token       N/A      False       N/A              NaN
# ...          ...       ...        ...       ...              ...
# PANDO      Pando       N/A       True       N/A     2.000000e+09
# 1INCH      1inch       N/A       True       N/A     1.500000e+09
# WEB      Webcoin       N/A       True       N/A     1.000000e+10
# TUSD    True USD       N/A       True       N/A     9.808949e+08
# SIP    Space SIP       N/A      False       N/A     9.997269e+08
#
#        TotalCoinSupply
# 42                 0.0
# 300              300.0
# 365                0.0
# 404                0.0
# 433                NaN
# ...                ...
# PANDO             -1.0
# 1INCH             -1.0
# WEB               -1.0
# TUSD              -1.0
# SIP               -1.0
#
# [7304 rows x 6 columns]

# %%
if not os.path.exists("Resources"):
    os.makedirs("Resources")
df.to_csv("Resources/crypto_raw_data.csv", index=False)
